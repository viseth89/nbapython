# %% [markdown]
# # Analysis of the 1996-97 Denver Nuggets

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# ## Importing 4 Essentials and styles to make the charts/tables easier to view

# %%
team = pd.DataFrame.from_csv('data/spurs1997.csv', encoding='utf-8')

# %%
t = team

# %% [markdown]
# ## Storing CSV -> into team Variable -> Stored as t for easier manipulation/calling

# %% [markdown]
# ### Storing Wins and Losses, Assists, Total Rebounds, Offensive Rebounds, Turnovers, Steals, Blocks

# %%
wins = t[t["W/L"]=='W']
loss = t[t['W/L']=='L']
assist_w=t[t['AST']>t['AST.1']]
assist_l=t[t['AST']<t['AST.1']]
trebounds_w=t[t['TRB']>t['TRB.1']]
trebounds_l=t[t['TRB']<t['TRB.1']]
orb_w=t[t['ORB']>t['ORB.1']]
orb_l=t[t['ORB']<t['ORB.1']]
to_w=t[t['TOV']>t['TOV.1']]
to_l=t[t['TOV']<t['TOV.1']]
stl_w=t[t['STL']>t['STL.1']]
stl_l=t[t['STL']<t['STL.1']]
blk_w=t[t['BLK']>t['BLK.1']]
blk_l=t[t['BLK']<t['BLK.1']]

# %%
print ("The Team won :", str(len(wins)), 'Games')
print ("The Team lost :", str(len(loss)), 'Games')
print ()
print ("The Team got more Assists than the Opponents:", str(len(assist_w)), 'Games')
print ("The Team got less Assists than the Opponents:", str(len(assist_l)), 'Games')
print()
print ("The Team got more Rebounded the Opponents:", str(len(trebounds_w)), 'Games')
print ("The Team got less Rebounded by the Opponents:", str(len(trebounds_l)), 'Games')
print()
print ("The Team got more Offensive Rebounds than the Opponents:", str(len(orb_w)), 'Games')
print ("The Team got less Offensive Rebounds than the Opponents:", str(len(orb_l)), 'Games')
print()
print ("The Team Turned Over the Ball less than the opponents in:", str(len(to_w)), 'Games')
print ("The Team Turned Over the Ball more than the opponents in:", str(len(to_w)), 'Games')
print()
print ("The Team got more Steals than the Opponents:", str(len(stl_w)), 'Games')
print ("The Team got less Steals than the Opponents:", str(len(stl_l)), 'Games')
print()
print ("The Team got more Blocks than the Opponents:", str(len(blk_w)), 'Games')
print ("The Team got less Blocks than the Opponents:", str(len(blk_l)), 'Games')
# Out:
# The Team won : 56 Games
# The Team lost : 26 Games
#
# The Team got more Assists than the Opponents: 54 Games
# The Team got less Assists than the Opponents: 20 Games
#
# The Team got more Rebounded the Opponents: 56 Games
# The Team got less Rebounded by the Opponents: 24 Games
#
# The Team got more Offensive Rebounds than the Opponents: 34 Games
# The Team got less Offensive Rebounds than the Opponents: 40 Games
#
# The Team Turned Over the Ball less than the opponents in: 64 Games
# The Team Turned Over the Ball more than the opponents in: 64 Games
#
# The Team got more Steals than the Opponents: 12 Games
# The Team got less Steals than the Opponents: 60 Games
#
# The Team got more Blocks than the Opponents: 56 Games
# The Team got less Blocks than the Opponents: 19 Games

# %% [markdown]
# ### Storing Rebounds and Rebounds Won with Rebounds Edge & Storing Assists and Games won with Assist Edge

# %%
wrebounds_w=trebounds_w[trebounds_w["W/L"] =="W"]
wassist_w=assist_w[assist_w['W/L']=='W']

# %%
wpct = (len(wrebounds_w)) / (len(trebounds_w))
print("With the edge in Rebounding in, they were able to capitalize in", str(len(wrebounds_w)), 'of' , str(len(trebounds_w)))
print('A Percentage of', str(wpct), 'percent')
# Out:
# With the edge in Rebounding in, they were able to capitalize in 45 of 56
# A Percentage of 0.8035714285714286 percent

# %%
wwpct = (len(wassist_w)) / (len(assist_w))
print("With the edge in Assist in, they were able to capitalize in", str(len(wassist_w)), 'of' , str(len(assist_w)))
print('A Percentage of', str(wwpct), 'percent')
# Out:
# With the edge in Assist in, they were able to capitalize in 45 of 54
# A Percentage of 0.8333333333333334 percent

# %% [markdown]
# ### Storing Games with Both Assists and Rebounds Edge

# %%
astreb = assist_w[assist_w['TRB'] > assist_w['TRB.1']]

# %% [markdown]
# ### Storing Games Won with Both Assists and Rebounds Edge

# %%
astrebw = astreb[astreb['W/L']=='W']

# %%
wwwpct = len(astrebw)/len(astreb)
print("With the edge in Rebounding in and assist, they were able to capitalize in ", str(len(astrebw)), 'of' , str(len(astreb)))
print('A Percentage of', str(wwwpct), 'percent')
# Out:
# With the edge in Rebounding in and assist, they were able to capitalize in  37 of 40
# A Percentage of 0.925 percent

# %%
t
# Out:
#      G        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA    FG%  ...   \
# Rk                                                                  ...
# 1    1  1997-10-31          @  DEN   W  107     96  40   74  0.541  ...
# 2    2  1997-11-01        NaN  CLE   W   83     80  31   62  0.500  ...
# 3    3  1997-11-03          @  CHI   L   83     87  34   85  0.400  ...
# 4    4  1997-11-05        NaN  VAN   W   87     79  37   83  0.446  ...
# 5    5  1997-11-08        NaN  UTA   W   87     80  30   70  0.429  ...
# 6    6  1997-11-10          @  TOR   W  100     98  41   65  0.631  ...
# 7    7  1997-11-11          @  MIN   W   93     92  35   82  0.427  ...
# 8    8  1997-11-13        NaN  LAL   L  100    109  37   75  0.493  ...
# 9    9  1997-11-15        NaN  MIN   L   94    105  29   75  0.387  ...
# 10  10  1997-11-19        NaN  GSW   W  108     87  37   72  0.514  ...
# 11  11  1997-11-21          @  SEA   L   74     94  28   82  0.341  ...
# 12  12  1997-11-22          @  UTA   L   74    103  27   73  0.370  ...
# 13  13  1997-11-25          @  DAL   W  102     91  41   75  0.547  ...
# 14  14  1997-11-26        NaN  WAS   L   94     98  38   75  0.507  ...
# 15  15  1997-11-29        NaN  DAL   W   96     87  37   76  0.487  ...
# 16  16  1997-11-30          @  ATL   L   96    108  40   75  0.533  ...
# 17  17  1997-12-02        NaN  NYK   W   90     84  32   71  0.451  ...
# 18  18  1997-12-04          @  LAC   L   96    100  39   86  0.453  ...
# 19  19  1997-12-05          @  LAL   L   88     98  34   76  0.447  ...
# 20  20  1997-12-09          @  HOU   L   78    108  31   90  0.344  ...
# 21  21  1997-12-10        NaN  LAC   W  102     87  34   71  0.479  ...
# 22  22  1997-12-13        NaN  ORL   W  107     78  49   78  0.628  ...
# 23  23  1997-12-16          @  DEN   W   99     85  38   72  0.528  ...
# 24  24  1997-12-17        NaN  VAN   W   98     87  39   82  0.476  ...
# 25  25  1997-12-20        NaN  HOU   W  100     87  42   83  0.506  ...
# 26  26  1997-12-23        NaN  IND   W   91     79  33   66  0.500  ...
# 27  27  1997-12-26        NaN  BOS   W  101     86  35   64  0.547  ...
# 28  28  1997-12-28          @  POR   L   79     82  28   79  0.354  ...
# 29  29  1997-12-30          @  VAN   W  124    115  39   69  0.565  ...
# 30  30  1998-01-02        NaN  POR   W   85     69  30   64  0.469  ...
# ..  ..         ...        ...  ...  ..  ...    ...  ..  ...    ...  ...
# 53  53  1998-02-21        NaN  UTA   L   77     79  28   67  0.418  ...
# 54  54  1998-02-22          @  PHO   L   79     97  29   68  0.426  ...
# 55  55  1998-02-24        NaN  MIN   W  105     99  37   82  0.451  ...
# 56  56  1998-02-26        NaN  TOR   W   97     86  36   76  0.474  ...
# 57  57  1998-02-28        NaN  PHI   W  100     88  40   76  0.526  ...
# 58  58  1998-03-02          @  SAC   W  116     95  44   76  0.579  ...
# 59  59  1998-03-04          @  GSW   L   83     90  32   73  0.438  ...
# 60  60  1998-03-06          @  LAL   L   84     91  34   78  0.436  ...
# 61  61  1998-03-08          @  POR   W   82     78  32   73  0.438  ...
# 62  62  1998-03-10        NaN  NJN   W   79     78  30   66  0.455  ...
# 63  63  1998-03-12        NaN  SAC   W   97     86  38   87  0.437  ...
# 64  64  1998-03-14        NaN  CHI   L   86     96  35   77  0.455  ...
# 65  65  1998-03-16        NaN  MIL   W   96     85  40   74  0.541  ...
# 66  66  1998-03-18          @  MIN   W   92     76  33   69  0.478  ...
# 67  67  1998-03-20        NaN  CHH   L   82     92  35   77  0.455  ...
# 68  68  1998-03-22        NaN  PHO   W   93     83  36   86  0.419  ...
# 69  69  1998-03-24          @  CLE   W   86     85  30   66  0.455  ...
# 70  70  1998-03-25          @  DET   L   94    103  37   78  0.474  ...
# 71  71  1998-03-27          @  PHI   W  110     85  39   71  0.549  ...
# 72  72  1998-03-29          @  IND   W   74     55  26   65  0.400  ...
# 73  73  1998-03-31          @  NYK   W   95     78  35   72  0.486  ...
# 74  74  1998-04-02        NaN  MIA   W  103     89  42   80  0.525  ...
# 75  75  1998-04-04        NaN  GSW   W   88     80  32   73  0.438  ...
# 76  76  1998-04-06        NaN  POR   L   75     79  26   73  0.356  ...
# 77  77  1998-04-08          @  UTA   L   88     98  33   69  0.478  ...
# 78  78  1998-04-10        NaN  SEA   W   99     84  39   79  0.494  ...
# 79  79  1998-04-13        NaN  LAL   L   75     99  26   84  0.310  ...
# 80  80  1998-04-16          @  VAN   W  110     97  43   84  0.512  ...
# 81  81  1998-04-17          @  SEA   W   89     87  30   64  0.469  ...
# 82  82  1998-04-19        NaN  DEN   W   96     82  38   76  0.500  ...
#
#     FT.1  FTA.1  FT%.1  ORB.1  TRB.1  AST.1  STL.1  BLK.1  TOV.1  PF.1
# Rk
# 1     20     26  0.769     14     34     12      9      3     13    30
# 2     25     34  0.735     18     42     18     16      2     15    23
# 3     15     24  0.625     26     60     21     12      9     13    27
# 4     10     17  0.588     13     42     22      6      5     16    17
# 5     39     53  0.736     10     33     13     10      3     17    36
# 6     17     24  0.708     19     34     24     15      5     11    17
# 7     12     16  0.750      8     27     23      9      6     13    23
# 8     22     33  0.667     10     39     23      7      7     15    22
# 9     38     48  0.792     13     54     21     10      3      5    31
# 10    14     20  0.700     14     39     24      9      7     12    26
# 11    13     18  0.722      9     46     26     13      5     14    24
# 12    31     39  0.795     11     41     25      7      6     18    30
# 13     9     12  0.750     12     34     18      8      9     13    16
# 14    13     30  0.433      8     34     25     12      6      9    26
# 15    14     20  0.700     14     36     15      8      1     14    22
# 16    15     24  0.625     12     35     30      9      3      8    22
# 17    19     26  0.731     14     45     18      8      5     13    28
# 18    17     26  0.654      9     45     14      6     10     13    28
# 19    25     28  0.893     14     40     23      8      6     15    20
# 20    18     24  0.750      7     46     28      9      6     13    16
# 21    13     20  0.650     13     41     18      6      1     11    24
# 22    11     15  0.733     14     35     15      8      6     19    16
# 23    23     30  0.767     17     40     14     13      2     11    21
# 24    20     23  0.870     14     47     17      3      6     11    18
# 25    23     28  0.821      8     43     10      7      3     13    20
# 26    17     22  0.773      6     32     16      8      4     12    25
# 27     8     10  0.800      8     25     15     17      4     14    28
# 28    17     27  0.630     11     47     11      7      7     13    21
# 29    15     19  0.789     13     38     28      9      3      6    26
# 30    16     28  0.571      8     37     11     10      4     12    24
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 53    28     33  0.848      8     36     13     11      1     16    26
# 54     9     13  0.692      7     37     33     12      4     13    14
# 55    24     31  0.774     12     41     23     14      3     13    29
# 56     8     16  0.500     14     40     19     14      7     16    28
# 57    16     20  0.800     19     43     22      3      9      5    24
# 58    25     36  0.694     14     37     23      5      6     10    27
# 59    17     21  0.810     13     40     21     17      7     17    24
# 60    27     38  0.711     12     32     20     14      7     16    17
# 61    20     22  0.909     17     48     19      6      3     13    22
# 62    27     31  0.871     16     37     11     13      2     15    23
# 63    15     22  0.682      9     39     18      7      3     14    18
# 64    15     17  0.882     15     42     20      8      4     12    19
# 65    18     23  0.783     16     33     20     15      7     12    20
# 66    10     16  0.625     19     44     27      6      3      9    23
# 67    23     28  0.821      8     38     21      6      1     14    22
# 68    16     23  0.696      7     42     14      7      3     10    19
# 69    13     17  0.765     10     35     23      9      4     12    27
# 70    25     31  0.806      7     35     24      7      3     11    20
# 71    15     21  0.714     13     33     20      6      5     18    27
# 72    11     13  0.846     15     41      9      7      1     14    20
# 73     4      7  0.571     11     33     25      6      1      7    22
# 74    29     37  0.784     12     37     18      8      2      7    27
# 75    16     21  0.762      9     34     12      5      8     15    28
# 76     7     11  0.636     10     39     20      7      8     13    22
# 77    34     40  0.850     13     43     17      8      4     11    20
# 78    11     17  0.647      8     35     18      6      3      9    15
# 79    19     33  0.576      5     48     21      7      5     11    22
# 80    26     27  0.963     15     44     20      7      7     13    20
# 81    14     23  0.609      9     37     22     11      1     12    29
# 82    15     20  0.750      8     39     15      8      4     16    17
#
# [82 rows x 40 columns]

# %%
t.plot(x='G', y='Tm',kind='scatter')
