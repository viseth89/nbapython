# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
'''
reload(sys)
sys.setdefaulencoding('utf-8')
'''
# Out:
# "\nreload(sys)\nsys.setdefaulencoding('utf-8')\n"

# %%
bulls = pd.read_csv('1991b.csv')

# %%
b = pd.DataFrame.from_csv('1991b.csv')

# %%
def read_seq(text):
    with open(text, 'r') as seq:
        seq = seq.read()
    seq = seq.replace('\n','').replace('\r','')
    return seq

# %%
losses = b[b.WL == 'L']

# %%
wins = b[b.WL == 'W']

# %%
wins
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 5    5  1991-11-08        NaN  DAL  W  108     92  42   82  0.512 ...    18
# 6    6  1991-11-09        NaN  ORL  W  107     76  47   90  0.522 ...    23
# 7    7  1991-11-12        NaN  DET  W  110     93  42   80  0.525 ...    21
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 9    9  1991-11-15        NaN  MIL  W  114    101  46   79  0.582 ...    22
# 10  10  1991-11-20          @  GSW  W  112    108  42   81  0.519 ...    20
# 11  11  1991-11-22          @  SEA  W  112    109  40   83  0.482 ...    30
# 12  12  1991-11-23          @  DEN  W  107    100  46   91  0.505 ...    31
# ...

# %%
b['OAST']
# Out:
# Rk
# 1     25
# 2     22
# 3     28
# 4     28
# 5     20
# 6     14
# 7     19
# 8     28
# 9     23
# 10    16
# 11    21
# 12     9
# 13    20
# 14    20
# 15    17
# 16    23
# 17    22
# 18    19
# 19    19
# 20    19
# 21    16
# 22    17
# 23    19
# 24    20
# 25    20
# 26    30
# 27    28
# 28    26
# 29    20
# 30    23
#       ..
# 53    25
# 54    21
# 55    24
# 56    23
# 57    30
# 58    26
# 59    18
# 60    27
# 61    21
# 62    21
# 63    25
# 64    25
# 65    20
# 66    20
# 67    17
# 68    20
# 69    24
# 70    26
# 71    24
# 72    28
# 73    21
# 74    25
# 75    25
# 76    28
# 77    26
# 78    22
# 79    15
# 80    35
# 81    15
# 82    15
# Name: OAST, dtype: int64

# %%
b[AST]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-5ac2fefaa220> in <module>()
# ----> 1 b[AST]
#
# NameError: name 'AST' is not defined

# %%
ast = b[b['OAST'] >= 25]

# %% [markdown]
# # HOW DID WE ASSIGN THIS ONE, NOTICE THE QUOTES OVER '.'

# %%
ast
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 26  26  1991-12-26          @  ATL  W  122    111  49   85  0.576 ...    12
# 27  27  1991-12-28        NaN  SAC  W  127    118  46   90  0.511 ...    20
# 28  28  1991-12-30          @  IND  W  109    104  38   73  0.521 ...    24
# 33  33  1992-01-10        NaN  UTA  W  105     90  43   87  0.494 ...    24
# 37  37  1992-01-17        NaN  SAS  W  102     96  37   75  0.493 ...    17
# 39  39  1992-01-21        NaN  PHO  W  108    102  48   84  0.571 ...    12
# ...

# %%
eff = b[b['AST'] >= b['OAST']]

# %%
eff
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 5    5  1991-11-08        NaN  DAL  W  108     92  42   82  0.512 ...    18
# 6    6  1991-11-09        NaN  ORL  W  107     76  47   90  0.522 ...    23
# 7    7  1991-11-12        NaN  DET  W  110     93  42   80  0.525 ...    21
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 9    9  1991-11-15        NaN  MIL  W  114    101  46   79  0.582 ...    22
# 10  10  1991-11-20          @  GSW  W  112    108  42   81  0.519 ...    20
# 12  12  1991-11-23          @  DEN  W  107    100  46   91  0.505 ...    31
# ...

# %%
beff = b[b['OAST'] >= b['AST']]

# %%
beff
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 11  11  1991-11-22          @  SEA  W  112    109  40   83  0.482 ...    30
# 21  21  1991-12-14          @  WSB  W  113    100  43   86  0.500 ...    29
# 26  26  1991-12-26          @  ATL  W  122    111  49   85  0.576 ...    12
# 40  40  1992-01-22          @  CHH  W  115    112  43   83  0.518 ...    19
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 47  47  1992-02-03          @  UTA  L  123    126  47  112  0.420 ...    41
# 48  48  1992-02-05          @  PHO  L  114    126  48  101  0.475 ...    25
# ...

# %%
beff.to_csv("beff.csv")

# %%
beffl = beff[beff['WL'] == 'L']

# %%
beff.iloc[:,10:20]
# Out:
#     3P  3PA    3P%  FT  FTA    FT%  ORB  TRB  AST  STL
# Rk
# 6    1    6  0.167  12   16  0.750   19   57   30    8
# 12   0    3  0.000  15   18  0.833   14   48   16    6
# 14   1    9  0.111  17   27  0.630   12   44   34    8
# 23   0    3  0.000  29   34  0.853   17   42   22   10
# 24   5    7  0.714  12   19  0.632   15   37   33   13
# 53   4    7  0.571  20   27  0.741   18   39   30    9
# 59   4    9  0.444  17   24  0.708   11   44   34   11
# 79   1    5  0.200   9   14  0.643   18   51   32   11
# 82   1    5  0.200  30   36  0.833   11   36   25    7

# %%
beffl
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 47  47  1992-02-03          @  UTA  L  123    126  47  112  0.420 ...    41
# 48  48  1992-02-05          @  PHO  L  114    126  48  101  0.475 ...    25
# 56  56  1992-02-25          @  DET  L  106    108  44   90  0.489 ...    25
# 60  60  1992-03-03        NaN  IND  L  101    103  40   77  0.519 ...    17
# 69  69  1992-03-21        NaN  ORL  L  108    111  39   89  0.438 ...    14
# 75  75  1992-04-05          @  BOS  L   86     97  36   84  0.429 ...    17
# 80  80  1992-04-14          @  CLE  L  100    115  44   97  0.454 ...    15
#
#     OFTA   OFT%  OORB  OTRB  OAST  OSTL  OBLK  OTOV  OPF
# Rk
# ...

# %%
losses
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 18  18  1991-12-07          @  PHI  L  100    103  42   93  0.452 ...    23
# 22  22  1991-12-17        NaN  LAL  L   89    102  38   92  0.413 ...    30
# 29  29  1992-01-03          @  MIL  L  108    113  42   79  0.532 ...    18
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 47  47  1992-02-03          @  UTA  L  123    126  47  112  0.420 ...    41
# 48  48  1992-02-05          @  PHO  L  114    126  48  101  0.475 ...    25
# 52  52  1992-02-17        NaN  CLE  L  112    113  53   93  0.570 ...    24
# ...

# %%
reloss = losses[losses['OTRB'] > losses['TRB']]

# %%
reloss
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 22  22  1991-12-17        NaN  LAL  L   89    102  38   92  0.413 ...    30
# 29  29  1992-01-03          @  MIL  L  108    113  42   79  0.532 ...    18
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 56  56  1992-02-25          @  DET  L  106    108  44   90  0.489 ...    25
# 80  80  1992-04-14          @  CLE  L  100    115  44   97  0.454 ...    15
#
#     OFTA   OFT%  OORB  OTRB  OAST  OSTL  OBLK  OTOV  OPF
# Rk
# 3     29  0.690    14    44    28     9     5    18   33
# 22    35  0.857    17    49    17     6    10    12   15
# 29    29  0.621    16    37    20    10     3    10   23
# ...

# %%
randa = beffl[beffl['OTRB'] > beffl['TRB']]

# %%
randa
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 56  56  1992-02-25          @  DET  L  106    108  44   90  0.489 ...    25
# 80  80  1992-04-14          @  CLE  L  100    115  44   97  0.454 ...    15
#
#     OFTA   OFT%  OORB  OTRB  OAST  OSTL  OBLK  OTOV  OPF
# Rk
# 43    26  0.769    16    52    24     4    12    14   23
# 44    24  0.583    13    45    25     6    11    14   18
# 56    30  0.833    13    46    23     3     8    15   19
# 80    18  0.833     8    42    35     4     5    12   16
#
# [4 rows x 40 columns]

# %%
b
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 5    5  1991-11-08        NaN  DAL  W  108     92  42   82  0.512 ...    18
# 6    6  1991-11-09        NaN  ORL  W  107     76  47   90  0.522 ...    23
# 7    7  1991-11-12        NaN  DET  W  110     93  42   80  0.525 ...    21
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 9    9  1991-11-15        NaN  MIL  W  114    101  46   79  0.582 ...    22
# 10  10  1991-11-20          @  GSW  W  112    108  42   81  0.519 ...    20
# ...

# %%
wasst = b[b['AST']>b['OAST']]

# %%
wasst
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 5    5  1991-11-08        NaN  DAL  W  108     92  42   82  0.512 ...    18
# 6    6  1991-11-09        NaN  ORL  W  107     76  47   90  0.522 ...    23
# 7    7  1991-11-12        NaN  DET  W  110     93  42   80  0.525 ...    21
# 9    9  1991-11-15        NaN  MIL  W  114    101  46   79  0.582 ...    22
# 10  10  1991-11-20          @  GSW  W  112    108  42   81  0.519 ...    20
# 12  12  1991-11-23          @  DEN  W  107    100  46   91  0.505 ...    31
# 13  13  1991-11-26          @  LAC  W  116     79  49   85  0.576 ...    11
# ...

# %%
wrbd = b[b['TRB']>b['OTRB']]

# %%
wrbd
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 1    1  1991-11-01        NaN  PHI  W  110     90  49   91  0.538 ...    12
# 4    4  1991-11-06          @  BOS  W  132    113  50   84  0.595 ...    19
# 6    6  1991-11-09        NaN  ORL  W  107     76  47   90  0.522 ...    23
# 7    7  1991-11-12        NaN  DET  W  110     93  42   80  0.525 ...    21
# 8    8  1991-11-13          @  CHH  W  117     95  48   96  0.500 ...    13
# 9    9  1991-11-15        NaN  MIL  W  114    101  46   79  0.582 ...    22
# 10  10  1991-11-20          @  GSW  W  112    108  42   81  0.519 ...    20
# 12  12  1991-11-23          @  DEN  W  107    100  46   91  0.505 ...    31
# 13  13  1991-11-26          @  LAC  W  116     79  49   85  0.576 ...    11
# 15  15  1991-11-30          @  SAC  W  118    102  48   89  0.539 ...    26
# ...

# %%
lasst = b[b['AST']<b['OAST']]

# %%
lrbd = b[b['TRB']<b['OTRB']]

# %%
lasst
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 11  11  1991-11-22          @  SEA  W  112    109  40   83  0.482 ...    30
# 21  21  1991-12-14          @  WSB  W  113    100  43   86  0.500 ...    29
# 26  26  1991-12-26          @  ATL  W  122    111  49   85  0.576 ...    12
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 47  47  1992-02-03          @  UTA  L  123    126  47  112  0.420 ...    41
# 48  48  1992-02-05          @  PHO  L  114    126  48  101  0.475 ...    25
# 51  51  1992-02-15        NaN  NYK  W   99     98  37   79  0.468 ...    13
# 58  58  1992-02-28          @  MIL  W  109    105  43   78  0.551 ...    17
# ...

# %%
lrbd
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 5    5  1991-11-08        NaN  DAL  W  108     92  42   82  0.512 ...    18
# 11  11  1991-11-22          @  SEA  W  112    109  40   83  0.482 ...    30
# 14  14  1991-11-29          @  POR  W  116    114  49  107  0.458 ...    17
# 20  20  1991-12-13        NaN  NYK  W   99     89  39   76  0.513 ...    12
# 22  22  1991-12-17        NaN  LAL  L   89    102  38   92  0.413 ...    30
# 23  23  1991-12-20          @  NJN  W  115     98  43   98  0.439 ...    13
# 24  24  1991-12-21        NaN  ATL  W  117    103  50   91  0.549 ...    16
# 29  29  1992-01-03          @  MIL  L  108    113  42   79  0.532 ...    18
# 33  33  1992-01-10        NaN  UTA  W  105     90  43   87  0.494 ...    24
# ...

# %%
vl = b[b['WL']=='L']

# %%
vl
# Out:
#      G        Date Unnamed: 3  Opp WL   Tm  Opp.1  FG  FGA    FG% ...   OFT  \
# Rk                                                                ...
# 2    2  1991-11-02          @  MIL  L  107    109  41   81  0.506 ...    16
# 3    3  1991-11-05        NaN  GSW  L  110    118  39   84  0.464 ...    20
# 18  18  1991-12-07          @  PHI  L  100    103  42   93  0.452 ...    23
# 22  22  1991-12-17        NaN  LAL  L   89    102  38   92  0.413 ...    30
# 29  29  1992-01-03          @  MIL  L  108    113  42   79  0.532 ...    18
# 43  43  1992-01-28          @  SAS  L  104    109  42   96  0.438 ...    20
# 44  44  1992-01-30          @  HOU  L  102    105  43   95  0.453 ...    14
# 47  47  1992-02-03          @  UTA  L  123    126  47  112  0.420 ...    41
# 48  48  1992-02-05          @  PHO  L  114    126  48  101  0.475 ...    25
# 52  52  1992-02-17        NaN  CLE  L  112    113  53   93  0.570 ...    24
# ...
