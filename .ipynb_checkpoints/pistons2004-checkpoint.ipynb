# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import json
# %matplotlib inline

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# learned from youtube video brandon rhodes on pandas
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df = pd.read_csv('data/warriors2015.csv')

# %%
df.head()
# Out:
#    Rk  G        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA  ...   FT.1  \
# 0   1  1  2014-10-29          @  SAC   W   95     77  33   75  ...     26
# 1   2  2  2014-11-01        NaN  LAL   W  127    104  46   83  ...     18
# 2   3  3  2014-11-02          @  POR   W   95     90  36   81  ...      9
# 3   4  4  2014-11-05        NaN  LAC   W  121    104  43   74  ...     21
# 4   5  5  2014-11-08          @  HOU   W   98     87  39   87  ...     17
#
#    FTA.1  FT%.1  ORB.1  TRB.1  AST.1  STL.1  BLK.1  TOV.1  PF.1
# 0     35  0.743     15     50     13     11      3     26    26
# 1     25  0.720     17     37     21      9      3     22    27
# 2     14  0.643     17     56     20      9      2     19    19
# 3     27  0.778      5     30     26     12      2     14    14
# 4     21  0.810     16     46     13     14      0     22    17
#
# [5 rows x 41 columns]

# %%
stats = {
    'wins' : df[df["W/L"]=='W'],
    'loss' : df[df['W/L']=='L'],
    'assist_w':df[df['AST']>df['AST.1']],
    'assist_l':df[df['AST']<df['AST.1']]
    'trebounds_w':df[df['TRB']>df['TRB.1']]
    'trebounds_l':df[df['TRB']<df['TRB.1']]
    'orb_w':df[df['ORB']>df['ORB.1']]
    'orb_l':df[df['ORB']<df['ORB.1']]
    'to_w':df[df['TOV']>df['TOV.1']]
    'to_l':df[df['TOV']<df['TOV.1']]
    'stl_w':df[df['STL']>df['STL.1']]
    'stl_l':df[df['STL']<df['STL.1']]
    'blk_w':df[df['BLK']>df['BLK.1']]
    'blk_l':df[df['BLK']<df['BLK.1']]
}

# %%
stats['wins']
# Out:
#     Rk   G        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA  ...   FT.1  \
# 0    1   1  2014-10-29          @  SAC   W   95     77  33   75  ...     26
# 1    2   2  2014-11-01        NaN  LAL   W  127    104  46   83  ...     18
# 2    3   3  2014-11-02          @  POR   W   95     90  36   81  ...      9
# 3    4   4  2014-11-05        NaN  LAC   W  121    104  43   74  ...     21
# 4    5   5  2014-11-08          @  HOU   W   98     87  39   87  ...     17
# 7    8   8  2014-11-13        NaN  BRK   W  107     99  41   90  ...     18
# 8    9   9  2014-11-15        NaN  CHO   W  112     87  45   87  ...     16
# 9   10  10  2014-11-16          @  LAL   W  136    115  46   86  ...     34
# 10  11  11  2014-11-21        NaN  UTA   W  101     88  41   82  ...     12
# 11  12  12  2014-11-23          @  OKC   W   91     86  33   93  ...     19
# 12  13  13  2014-11-25          @  MIA   W  114     97  43   75  ...     21
# 13  14  14  2014-11-26          @  ORL   W  111     96  44   85  ...     18
# 14  15  15  2014-11-28          @  CHO   W  106    101  42   99  ...     19
# 15  16  16  2014-11-30          @  DET   W  104     93  37   79  ...     16
# 16  17  17  2014-12-02        NaN  ORL   W   98     97  38   82  ...     13
# 17  18  18  2014-12-04        NaN  NOP   W  112     85  47  100  ...      8
# 18  19  19  2014-12-06          @  CHI   W  112    102  40   89  ...     23
# 19  20  20  2014-12-08          @  MIN   W  102     86  42   91  ...     20
# 20  21  21  2014-12-10        NaN  HOU   W  105     93  40   81  ...     10
# 21  22  22  2014-12-13          @  DAL   W  105     98  37   83  ...     21
# 22  23  23  2014-12-14          @  NOP   W  128    122  44   86  ...     20
# 24  25  25  2014-12-18        NaN  OKC   W  114    109  48   94  ...     16
# 25  26  26  2014-12-22        NaN  SAC   W  128    108  49   91  ...     14
# 15     24  0.667     15     44     25     11      5     13    20
# 16     14  0.929      8     40     19     11      3     11    17
# 17     13  0.615     10     47     23      8      4     17    15
# 18     27  0.852     17     50     24      6      3     22    23
# 19     29  0.690     18     49     22     12      4     19    10
# 20     15  0.667     12     44     15      9      2     15    17
# 21     30  0.700     17     53     14     11      0     15    23
# 22     25  0.800     12     44     22     14      6     13    27
# 24     24  0.667      8     43     17      5      4     15    15
# 25     21  0.667      9     39     31      5      5     13    17
# 28     36  0.583     13     47     29     10      5     24    18
# 29     23  0.609     18     48     16     11      2     27    16
# 30     20  0.750     11     37     23      7      1     15    16
# 31     34  0.765     20     59     19     10      5     11    25
# 32     23  0.957      5     41     24      4      2     17    19
# 33     23  0.739     14     45     13      8      1     14    14
# 34     24  0.833     11     44     14      7      7     15    18
# ..    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 45     24  0.792      6     34     17      7      4     18    21
# 46     28  0.786     14     42     24      8      1      8    19
# 48     17  0.824     15     44     23      7      1     13    20
# 49     14  0.786     10     52     21      9      4     27    19
# 50     27  0.741     11     50     18      7      2     12    14
# 51     20  0.750     10     44     25      6      4     16    20
# 53     21  0.857      9     45     23      4      4     26    20
# 55     28  0.821      8     42     15      6      3     19    17
# 56     17  0.765     21     60     21      4      3      8    17
# 58     25  0.800     16     47     17     11      1     23    19
# 59     26  0.731      3     34     17     15      1     11    20
# 60     14  0.714      9     39     25      8      3     18    22
# 61     23  0.783      6     37     13     11      1     18    19
# 62     12  0.833     19     49     18      6      5     13    16
# 64     16  0.563     20     51     25      6     10     15    16
# 65     21  0.905     10     45     24     11      5     18    19
# 66     30  0.833     15     44     24     14      4     15    20
# 67     22  0.864      9     42     22      4      3     20    17
# 68     21  0.810      8     35     19      5      2     15    19
# 69     26  0.731      5     38     15      5      2     11    15
# 70     19  0.789     12     35     23      9      2     10    14
# 71     15  0.733      8     40     19      9      2     19    18
# 72     32  0.844     15     42     24     14      5     15    20
# 73     33  0.848     10     41     19      4      8     11    24
# 74     26  0.654      9     47     25      6      3     11    16
# 75     54  0.722     10     44     14      6      2     16    23
# 78      8  0.750     11     41     28      6      5      9    12
# 79     26  0.769      8     40     27      9      4     15    22
# 80     25  0.800     18     44     24     11      4     15    22
# 81     36  0.833      9     40     28     10      4     21    25
#
# [67 rows x 41 columns]

# %%
wins = t[t["W/L"]=='W']
loss = t[t['W/L']=='L']
assist_w=t[t['AST']>t['AST.1']]
assist_l=t[t['AST']<t['AST.1']]
trebounds_w=t[t['TRB']>t['TRB.1']]
trebounds_l=t[t['TRB']<t['TRB.1']]
orb_w=t[t['ORB']>t['ORB.1']]
orb_l=t[t['ORB']<t['ORB.1']]
to_w=t[t['TOV']>t['TOV.1']]
to_l=t[t['TOV']<t['TOV.1']]
stl_w=t[t['STL']>t['STL.1']]
stl_l=t[t['STL']<t['STL.1']]
blk_w=t[t['BLK']>t['BLK.1']]
blk_l=t[t['BLK']<t['BLK.1']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-28d212ad82b3> in <module>()
# ----> 1 wins = t[t["W/L"]=='W']
#       2 loss = t[t['W/L']=='L']
#       3 assist_w=t[t['AST']>t['AST.1']]
#       4 assist_l=t[t['AST']<t['AST.1']]
#       5 trebounds_w=t[t['TRB']>t['TRB.1']]
#
# NameError: name 't' is not defined

# %%
stats = {'Wins': wins['W/L'], 
        'Loss': loss['W/L'], 
        'Class': 'First',
        'Age': 7, 
        'Class': 'First',
        'Age': 7, 
        'Class': 'First',
        'Age': 7, 
        'Class': 'First',
        'Age': 7, 
        'Class': 'First',
        'Age': 7, 
        'Class': 'First'}
