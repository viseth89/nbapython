# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("knicks1997.csv")

# %%
df
# Out:
#     Rk   G        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA  ...   FT.1  \
# 0    1   1  1997-10-31          @  CHH   W   97     85  36   69  ...     30
# 1    2   2  1997-11-02        NaN  DET   L   86     94  32   74  ...     29
# 2    3   3  1997-11-04        NaN  BOS   W  102     70  33   68  ...     11
# 3    4   4  1997-11-06          @  PHO   W  105     75  43   89  ...     18
# 4    5   5  1997-11-07          @  LAL   L   94     99  32   78  ...     35
# 5    6   6  1997-11-09          @  SAC   L   78     86  35   78  ...     22
# 6    7   7  1997-11-11        NaN  DEN   W   93     90  36   74  ...     17
# 7    8   8  1997-11-12          @  TOR   W   93     70  37   81  ...     13
# 8    9   9  1997-11-15        NaN  SAC   W  114     87  41   75  ...     16
# 9   10  10  1997-11-18          @  HOU   L   84     95  28   76  ...     34
# 10  11  11  1997-11-20          @  ATL   W  100     79  44   84  ...     22
# ...

# %%
df.set_index('G')
# Out:
#     Rk        Date Unnamed: 3  Opp W/L   Tm  Opp.1  FG  FGA    FG%  ...   \
# G                                                                   ...
# 1    1  1997-10-31          @  CHH   W   97     85  36   69  0.522  ...
# 2    2  1997-11-02        NaN  DET   L   86     94  32   74  0.432  ...
# 3    3  1997-11-04        NaN  BOS   W  102     70  33   68  0.485  ...
# 4    4  1997-11-06          @  PHO   W  105     75  43   89  0.483  ...
# 5    5  1997-11-07          @  LAL   L   94     99  32   78  0.410  ...
# 6    6  1997-11-09          @  SAC   L   78     86  35   78  0.449  ...
# 7    7  1997-11-11        NaN  DEN   W   93     90  36   74  0.486  ...
# 8    8  1997-11-12          @  TOR   W   93     70  37   81  0.457  ...
# 9    9  1997-11-15        NaN  SAC   W  114     87  41   75  0.547  ...
# 10  10  1997-11-18          @  HOU   L   84     95  28   76  0.368  ...
# 11  11  1997-11-20          @  ATL   W  100     79  44   84  0.524  ...
# ...
